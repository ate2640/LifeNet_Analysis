# %% [markdown]
# First and foremost, upload the dataset using pandas:

# %%
import pandas as pd
Organ_dataset = pd.read_csv('Organ Procurement Data Analysis.csv')

# %%
Organ_dataset.head()
# Out:
#   OPO code  Total number of transplants - OPO year 1  \
# 0     ALOB                                       300
# 1     AROR                                       122
# 2     AZOB                                       467
# 3     CADN                                       617
# 4     CAGS                                       247
#
#    Race (%) - White - OPO year 1  Race (%) - African-American - OPO year 1  \
# 0                      32.666667                                 58.000000
# 1                      32.786885                                 41.803279
# 2                      35.546039                                 14.989293
# 3                      21.069692                                 12.641815
# 4                      23.886640                                 14.170040
#
#    Race (%) - Hispanic/Latino - OPO year 1  Race (%) - Asian - OPO year 1  \
# 0                                 6.333333                       2.333333
# ...

# %%
Organ_dataset.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Per the email, this dataset contains information from two years. I'll subdivide the dataset into year 1 & year 2, respectively:

# %%
Organ_dataset.columns
# Out:
# Index(['OPO code', 'Total number of transplants - OPO year 1',
#        'Race (%) - White - OPO year 1',
#        'Race (%) - African-American - OPO year 1',
#        'Race (%) - Hispanic/Latino - OPO year 1',
#        'Race (%) - Asian - OPO year 1', 'Race (%) - Other - OPO year 1',
#        'Race (%) - Unknown - OPO year 1',
#        'Age Group (%) - <2 years - OPO year 1',
#        'Age Group (%) - 2-11 years - OPO year 1',
#        'Age Group (%) - 12-17 years - OPO year 1',
#        'Age Group (%) - 18-34 years - OPO year 1',
#        'Age Group (%) - 35-49 years - OPO year 1',
#        'Age Group (%) - 50-64 years - OPO year 1',
#        'Age Group (%) - 65+ years - OPO year 1',
#        'Gender (%) - Female - OPO year 1', 'Gender (%) - Male - OPO year 1',
#        'Total number of transplants - OPO year 2',
#        'Race (%) - White - OPO year 2',
#        'Race (%) - African-American - OPO year 2',
#        'Race (%) - Hispanic/Latino - OPO year 2',
# ...

# %%
organ_dataset_year1 = Organ_dataset[['OPO code', 'Total number of transplants - OPO year 1',
       'Race (%) - White - OPO year 1',
       'Race (%) - African-American - OPO year 1',
       'Race (%) - Hispanic/Latino - OPO year 1',
       'Race (%) - Asian - OPO year 1', 'Race (%) - Other - OPO year 1',
       'Race (%) - Unknown - OPO year 1',
       'Age Group (%) - <2 years - OPO year 1',
       'Age Group (%) - 2-11 years - OPO year 1',
       'Age Group (%) - 12-17 years - OPO year 1',
       'Age Group (%) - 18-34 years - OPO year 1',
       'Age Group (%) - 35-49 years - OPO year 1',
       'Age Group (%) - 50-64 years - OPO year 1',
       'Age Group (%) - 65+ years - OPO year 1',
       'Gender (%) - Female - OPO year 1', 'Gender (%) - Male - OPO year 1']]
organ_dataset_year1.head()
# Out:
#   OPO code  Total number of transplants - OPO year 1  \
# 0     ALOB                                       300
# 1     AROR                                       122
# 2     AZOB                                       467
# 3     CADN                                       617
# 4     CAGS                                       247
#
#    Race (%) - White - OPO year 1  Race (%) - African-American - OPO year 1  \
# 0                      32.666667                                 58.000000
# 1                      32.786885                                 41.803279
# 2                      35.546039                                 14.989293
# 3                      21.069692                                 12.641815
# 4                      23.886640                                 14.170040
#
#    Race (%) - Hispanic/Latino - OPO year 1  Race (%) - Asian - OPO year 1  \
# 0                                 6.333333                       2.333333
# ...

# %%
organ_dataset_year1.columns
# Out:
# Index(['OPO code', 'Total number of transplants - OPO year 1',
#        'Race (%) - White - OPO year 1',
#        'Race (%) - African-American - OPO year 1',
#        'Race (%) - Hispanic/Latino - OPO year 1',
#        'Race (%) - Asian - OPO year 1', 'Race (%) - Other - OPO year 1',
#        'Race (%) - Unknown - OPO year 1',
#        'Age Group (%) - <2 years - OPO year 1',
#        'Age Group (%) - 2-11 years - OPO year 1',
#        'Age Group (%) - 12-17 years - OPO year 1',
#        'Age Group (%) - 18-34 years - OPO year 1',
#        'Age Group (%) - 35-49 years - OPO year 1',
#        'Age Group (%) - 50-64 years - OPO year 1',
#        'Age Group (%) - 65+ years - OPO year 1',
#        'Gender (%) - Female - OPO year 1', 'Gender (%) - Male - OPO year 1'],
#       dtype='object')

# %%
organ_dataset_year2 = Organ_dataset[['OPO code',  'Total number of transplants - OPO year 2',
       'Race (%) - White - OPO year 2',
       'Race (%) - African-American - OPO year 2',
       'Race (%) - Hispanic/Latino - OPO year 2',
       'Race (%) - Asian - OPO year 2', 'Race (%) - Other - OPO year 2',
       'Race (%) - Unknown - OPO year 2',
       'Age Group (%) - <2 years - OPO year 2',
       'Age Group (%) - 2-11 years - OPO year 2',
       'Age Group (%) - 12-17 years - OPO year 2',
       'Age Group (%) - 18-34 years - OPO year 2',
       'Age Group (%) - 35-49 years - OPO year 2',
       'Age Group (%) - 50-64 years - OPO year 2',
       'Age Group (%) - 65+ years - OPO year 2',
       'Gender (%) - Female - OPO year 2', 'Gender (%) - Male - OPO year 2']]
organ_dataset_year2.head()
# Out:
#   OPO code  Total number of transplants - OPO year 2  \
# 0     ALOB                                       283
# 1     AROR                                       178
# 2     AZOB                                       390
# 3     CADN                                       561
# 4     CAGS                                       214
#
#    Race (%) - White - OPO year 2  Race (%) - African-American - OPO year 2  \
# 0                      27.561837                                 61.837456
# 1                      30.337079                                 45.505618
# 2                      34.871795                                 16.923077
# 3                      20.677362                                 13.012478
# 4                      25.233645                                 12.616822
#
#    Race (%) - Hispanic/Latino - OPO year 2  Race (%) - Asian - OPO year 2  \
# 0                                 6.360424                       3.533569
# ...

# %% [markdown]
# As mentioned in the email, the yellow highlighted row from the attached spreadsheet represents LifeNet and has OPO Code 'VATB' and row value of 53. We will use this as a reference in subsequent analyses.

# %%
print("In year 1, there were", organ_dataset_year1['Total number of transplants - OPO year 1'].sum(), "organ transplants")
print( 'VATB accounted for',organ_dataset_year1.iloc[53]['Total number of transplants - OPO year 1'],'transplants from this year')
print("VATB accounted for",round(100*(325/18787),2),"% of transplants from this year")
# Out:
# In year 1, there were 18787 organ transplants
# VATB accounted for 325 transplants from this year
# VATB accounted for 1.73 % of transplants from this year

# %%
print("In year 2, there were", organ_dataset_year2['Total number of transplants - OPO year 2'].sum(), "organ transplants")
print( 'VATB accounted for',organ_dataset_year2.iloc[53]['Total number of transplants - OPO year 2'],'transplants from this year')
print("VATB accounted for",round(100*(299/18602),2),"% of transplants from this year")
# Out:
# In year 2, there were 18602 organ transplants
# VATB accounted for 299 transplants from this year
# VATB accounted for 1.61 % of transplants from this year

# %%
organ_dataset_year1.iloc[53]
# Out:
# OPO code                                         VATB
# Total number of transplants - OPO year 1          325
# Race (%) - White - OPO year 1               30.153846
# Race (%) - African-American - OPO year 1    55.692308
# Race (%) - Hispanic/Latino - OPO year 1      6.153846
# Race (%) - Asian - OPO year 1                6.769231
# Race (%) - Other - OPO year 1                1.230769
# Race (%) - Unknown - OPO year 1                     0
# Age Group (%) - <2 years - OPO year 1        0.615385
# Age Group (%) - 2-11 years - OPO year 1      0.615385
# Age Group (%) - 12-17 years - OPO year 1     1.846154
# Age Group (%) - 18-34 years - OPO year 1     6.153846
# Age Group (%) - 35-49 years - OPO year 1    21.230769
# Age Group (%) - 50-64 years - OPO year 1    45.538462
# Age Group (%) - 65+ years - OPO year 1           24.0
# Gender (%) - Female - OPO year 1            39.076923
# Gender (%) - Male - OPO year 1              60.923077
# Name: 53, dtype: object

# %%
organ_dataset_year2.iloc[53]
# Out:
# OPO code                                         VATB
# Total number of transplants - OPO year 2          299
# Race (%) - White - OPO year 2               31.103679
# Race (%) - African-American - OPO year 2    50.501672
# Race (%) - Hispanic/Latino - OPO year 2      9.364548
# Race (%) - Asian - OPO year 2                7.692308
# Race (%) - Other - OPO year 2                1.337793
# Race (%) - Unknown - OPO year 2                     0
# Age Group (%) - <2 years - OPO year 2             0.0
# Age Group (%) - 2-11 years - OPO year 2      2.006689
# Age Group (%) - 12-17 years - OPO year 2     1.337793
# Age Group (%) - 18-34 years - OPO year 2    11.036789
# Age Group (%) - 35-49 years - OPO year 2    23.745819
# Age Group (%) - 50-64 years - OPO year 2    43.143813
# Age Group (%) - 65+ years - OPO year 2      18.729097
# Gender (%) - Female - OPO year 2            40.468227
# Gender (%) - Male - OPO year 2              59.531773
# Name: 53, dtype: object

# %% [markdown]
# ### Individual LifeNet Analysis

# %% [markdown]
# The 35-49 & 50-64 age groups account for the largest recipients of organs with approximately 2/3 in both years, with 35-49
# accounting for 21.23% & 23.75% in Years 1 and 2, respectively, and 50-64 accounting for 45.54% & 43.14% in Years 1 & 2,
# respectively
#
# African-Americans account for more than half of recipients in both years, and there was a 5% drop in African-American recipients from Year 1 to Year 2
#
# Non-Whites accounted for the largest proportion of recipients, at roughly 69%
#
# There was a notable increase in Hispanic recipients, from 6.15% to 9.37%
#
# Men account for 3/5 of recipients in both years
#
# There was a 5% increase in recipients of the 18-34 age group
#
# There was a 5.3% decrease in receipients of the Senior Citizen group

# %% [markdown]
# ### Analysis Including Other Companies, Year 1

# %%
organ_dataset_year1.describe()
# Out:
#        Total number of transplants - OPO year 1  \
# count                                 57.000000
# mean                                 329.596491
# std                                  185.528382
# min                                   63.000000
# 25%                                  195.000000
# 50%                                  295.000000
# 75%                                  442.000000
# max                                  879.000000
#
#        Race (%) - White - OPO year 1  \
# count                      57.000000
# mean                       38.286968
# std                        13.957407
# min                        11.363636
# 25%                        28.761062
# 50%                        35.546039
# 75%                        49.640288
# max                        67.021277
#
#        Race (%) - African-American - OPO year 1  \
# count                                 57.000000
# mean                                  33.294865
# ...

# %%
organ_dataset_year1.iloc[53]
# Out:
# OPO code                                         VATB
# Total number of transplants - OPO year 1          325
# Race (%) - White - OPO year 1               30.153846
# Race (%) - African-American - OPO year 1    55.692308
# Race (%) - Hispanic/Latino - OPO year 1      6.153846
# Race (%) - Asian - OPO year 1                6.769231
# Race (%) - Other - OPO year 1                1.230769
# Race (%) - Unknown - OPO year 1                     0
# Age Group (%) - <2 years - OPO year 1        0.615385
# Age Group (%) - 2-11 years - OPO year 1      0.615385
# Age Group (%) - 12-17 years - OPO year 1     1.846154
# Age Group (%) - 18-34 years - OPO year 1     6.153846
# Age Group (%) - 35-49 years - OPO year 1    21.230769
# Age Group (%) - 50-64 years - OPO year 1    45.538462
# Age Group (%) - 65+ years - OPO year 1           24.0
# Gender (%) - Female - OPO year 1            39.076923
# Gender (%) - Male - OPO year 1              60.923077
# Name: 53, dtype: object

# %% [markdown]
# LifeNet accounted for slightly fewer transplants than on average, with 325 compared to 329
#
# LfeNet's African American recipients far surprass the average, with 55.7% compared to 33.3%

# %% [markdown]
# ### Analysis Including Other Companies, Year 2

# %%
organ_dataset_year2.describe()
# Out:
#        Total number of transplants - OPO year 2  \
# count                                 57.000000
# mean                                 326.350877
# std                                  187.690331
# min                                   69.000000
# 25%                                  199.000000
# 50%                                  292.000000
# 75%                                  423.000000
# max                                  957.000000
#
#        Race (%) - White - OPO year 2  \
# count                      57.000000
# mean                       35.527473
# std                        12.079657
# min                        12.000000
# 25%                        26.905830
# 50%                        33.960293
# 75%                        46.123260
# max                        60.301508
#
#        Race (%) - African-American - OPO year 2  \
# count                                 57.000000
# mean                                  33.828442
# ...

# %%
organ_dataset_year2.iloc[53]
# Out:
# OPO code                                         VATB
# Total number of transplants - OPO year 2          299
# Race (%) - White - OPO year 2               31.103679
# Race (%) - African-American - OPO year 2    50.501672
# Race (%) - Hispanic/Latino - OPO year 2      9.364548
# Race (%) - Asian - OPO year 2                7.692308
# Race (%) - Other - OPO year 2                1.337793
# Race (%) - Unknown - OPO year 2                     0
# Age Group (%) - <2 years - OPO year 2             0.0
# Age Group (%) - 2-11 years - OPO year 2      2.006689
# Age Group (%) - 12-17 years - OPO year 2     1.337793
# Age Group (%) - 18-34 years - OPO year 2    11.036789
# Age Group (%) - 35-49 years - OPO year 2    23.745819
# Age Group (%) - 50-64 years - OPO year 2    43.143813
# Age Group (%) - 65+ years - OPO year 2      18.729097
# Gender (%) - Female - OPO year 2            40.468227
# Gender (%) - Male - OPO year 2              59.531773
# Name: 53, dtype: object

# %% [markdown]
# LifeNet performed well below the average number of transplants, with 299 compared to 326
#
# The Female/Male recipient ratio remained consistent in both years, with roughly 2 women for every 3 men

# %%
organ_dataset_year2.iloc[53][2:8]
# Out:
# Race (%) - White - OPO year 2               31.103679
# Race (%) - African-American - OPO year 2    50.501672
# Race (%) - Hispanic/Latino - OPO year 2      9.364548
# Race (%) - Asian - OPO year 2                7.692308
# Race (%) - Other - OPO year 2                1.337793
# Race (%) - Unknown - OPO year 2                     0
# Name: 53, dtype: object

# %%
organ_dataset_year1.describe()
# Out:
#        Total number of transplants - OPO year 1  \
# count                                 57.000000
# mean                                 329.596491
# std                                  185.528382
# min                                   63.000000
# 25%                                  195.000000
# 50%                                  295.000000
# 75%                                  442.000000
# max                                  879.000000
#
#        Race (%) - White - OPO year 1  \
# count                      57.000000
# mean                       38.286968
# std                        13.957407
# min                        11.363636
# 25%                        28.761062
# 50%                        35.546039
# 75%                        49.640288
# max                        67.021277
#
#        Race (%) - African-American - OPO year 1  \
# count                                 57.000000
# mean                                  33.294865
# ...
